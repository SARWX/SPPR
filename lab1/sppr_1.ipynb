# %% [markdown]
# ### 1. вывести информацию о заведениях

# %%
import pandas as pd

dataset_file = "/home/ubuntu/SPPR/data-4275-2021-02-09.xlsx"

df = pd.read_excel(dataset_file)
df.head(5)
# Out:
#        ID                                               Name  global_id  \
# 0  151635                                            СМЕТАНА  637376221
# 1   77874                                             Родник  637376331
# 2   24309                                    Кафе «Академия»  637376349
# 3   27429  ГБОУ «Школа № 1430 имени Героя Социалистическо...  637376480
# 4  148815                                           Брусника  637376481
#
#   IsNetObject OperatingCompany TypeObject  \
# 0         нет              NaN       кафе
# 1         нет              NaN       кафе
# 2         нет              NaN       кафе
# 3         нет              NaN   столовая
# 4          да         Брусника       кафе
#
#                                    AdmArea           District  \
# 0  Северо-Восточный административный округ  Ярославский район
# 1       Центральный административный округ    Таганский район
# 2       Центральный административный округ    Таганский район
# ...

# %% [markdown]
# ### 2. Посчитать среднее количество мест

# %%
df['SeatsCount'].mean()
# Out:
# 49.73795251527974

# %% [markdown]
# ### 3. Посчитать количество заведений на Арбате

# %%
(df['District']=='район Арбат').sum()
# Out:
# 228

# %% [markdown]
# ### 4. Посчитать количество заведений в Ярославском районе, которые обладают социальными привелегиями

# %%
((df['District'] == 'Ярославский район') & (df['SocialPrivileges'] == "да")).sum()
# Out:
# 20

# %% [markdown]
# ### 5. Отсортировать по заведения Москвы по убыванию посадочных мест

# %%
df.sort_values('SeatsCount', ascending=False)
# Out:
#            ID                  Name   global_id IsNetObject OperatingCompany  \
# 8509   199696  Arena by Soho Family   918058125         нет              NaN
# 5572    80291    Банкетный зал Шелк   637549245         нет              NaN
# 5718    27750             Трапезная   637549654         нет              NaN
# 3268    27024            РУМ СЕРВИС   637534241         нет              NaN
# 2649    27026            РУМ СЕРВИС   637532639         нет              NaN
# ...       ...                   ...         ...         ...              ...
# 11739  246382           Наша шаурма  1026864271         нет              NaN
# 4147   112591    Буфетная продукция   637539782         нет              NaN
# 7082   190278                Шаурма   905399533         нет              NaN
# 11712  228002                Шаурма  1026863185         нет              NaN
# 12423  262576                Шаурма  1034726844         нет              NaN
#
#                               TypeObject  \
# ...
